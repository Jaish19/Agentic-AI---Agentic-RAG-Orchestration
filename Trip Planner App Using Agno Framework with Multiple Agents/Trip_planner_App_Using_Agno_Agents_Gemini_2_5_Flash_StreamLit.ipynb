# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaish19/Agentic-AI---Agentic-RAG-Orchestration/blob/main/Trip%20Planner%20App%20Using%20Agno%20Framework%20with%20Multiple%20Agents/Trip_planner_App_Using_Agno_Agents_Gemini_2_5_Flash_StreamLit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Jaish19/Agentic-AI---Agentic-RAG-Orchestration.git
# Out:
# Cloning into 'Agentic-AI---Agentic-RAG-Orchestration'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 104 (delta 42), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (104/104), 965.04 KiB | 9.75 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# !pip install agno google-search-results streamlit
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 124.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 145.5 MB/s eta 0:00:00
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32010 sha256=cdb201538203e19ead2ca52860903487edcc597b07964285480a9532938a1906
#   Stored in directory: /root/.cache/pip/wheels/0c/47/f5/89b7e770ab2996baf8c910e7353d6391e373075a0ac213519e
# Successfully built google-search-results
# ...

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 1 package in 2s
# ⠴

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 136.118.29.7

# %%
cd /content/Agentic-AI---Agentic-RAG-Orchestration/Trip Planner App Using Agno Framework with Multiple Agents
# Out:
# /content/Agentic-AI---Agentic-RAG-Orchestration/Trip Planner App Using Agno Framework with Multiple Agents

# %%
! streamlit run travel_agent_app.py & cloudflared tunnel --url http://localhost:8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.75.211.127:8501
#
# ⠦⠧⠇⠏⠋⠙⠹your url is: https://kind-days-push.loca.lt
#   Stopping...
# ^C
